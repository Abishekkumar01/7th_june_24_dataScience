# %% [markdown]
# #

# %% [markdown]
#  # Learn_Seaborn

# %%
# !pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\program files\python38\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\program files\python38\lib\site-packages (from seaborn) (1.24.3)
# Requirement already satisfied: pandas>=1.2 in c:\program files\python38\lib\site-packages (from seaborn) (2.0.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\iamab\appdata\roaming\python\python38\site-packages (from seaborn) (3.7.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\iamab\appdata\roaming\python\python38\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\iamab\appdata\roaming\python\python38\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\iamab\appdata\roaming\python\python38\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.44.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\iamab\appdata\roaming\python\python38\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\iamab\appdata\roaming\python\python38\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\iamab\appdata\roaming\python\python38\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\iamab\appdata\roaming\python\python38\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\iamab\appdata\roaming\python\python38\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\iamab\appdata\roaming\python\python38\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (6.1.1)
# Requirement already satisfied: pytz>=2020.1 in c:\program files\python38\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in c:\program files\python38\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\iamab\appdata\roaming\python\python38\site-packages (from importlib-resources>=3.2.0->matplotlib!=3.6.1,>=3.4->seaborn) (3.17.0)
# Requirement already satisfied: six>=1.5 in c:\users\iamab\appdata\roaming\python\python38\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)

# %%
import matplotlib.pyplot as plt 
import seaborn as sns 
import pandas as pd 
import numpy as np

# %%
df = sns.load_dataset('tips')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.columns = ['total_bill', 'tip', 'gender', 'smoker', 'day', 'time', 'member']

# %%
# sns.lineplot()
# sns.boxplot()
# sns.scatterplot() 
# sns.countplot() 
# sns.barplot()
# sns.histplot()
sns.scatterplot(x='total_bill',y='tip',data=df) 
plt.show()

# %%
sns.relplot(x='total_bill',y='tip',data=df)
plt.show()

# %%
sns.relplot(x='total_bill',y='tip',data=df,kind='line')
plt.show()

# %%
sns.relplot(x='total_bill',y='tip',data=df,hue='gender',style='smoker')
plt.show()

# %%
df
# Out:
#      total_bill   tip  gender smoker   day    time  member
# 0         16.99  1.01  Female     No   Sun  Dinner       2
# 1         10.34  1.66    Male     No   Sun  Dinner       3
# 2         21.01  3.50    Male     No   Sun  Dinner       3
# 3         23.68  3.31    Male     No   Sun  Dinner       2
# 4         24.59  3.61  Female     No   Sun  Dinner       4
# ..          ...   ...     ...    ...   ...     ...     ...
# 239       29.03  5.92    Male     No   Sat  Dinner       3
# 240       27.18  2.00  Female    Yes   Sat  Dinner       2
# 241       22.67  2.00    Male    Yes   Sat  Dinner       2
# 242       17.82  1.75    Male     No   Sat  Dinner       2
# 243       18.78  3.00  Female     No  Thur  Dinner       2
#
# [244 rows x 7 columns]

# %%
sns.relplot(x='total_bill',y='tip',data=df,hue='gender',style='smoker',col='time')
plt.show()

# %% [markdown]
# # The total bill for F/M

# %%
sns.relplot(x='total_bill',y='tip',data=df,hue='gender',col='day')
plt.show()

# %%
# df

# %%
female = df[df['gender'] == 'Female']

# %%
sns.relplot(x='tip',y='total_bill',data=female,hue='smoker',col='smoker')

# %% [markdown]
# ## only F

# %%
sns.relplot(x='tip',y='total_bill',data=female,hue='smoker',row='day')

# %%
df['day'].value_counts()
# Out:
# day
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: count, dtype: int64

# %%
sns.countplot(df['day'])
# Out:
# <Axes: xlabel='count', ylabel='day'>

# %%
import warnings 
warnings.filterwarnings('ignore')

# %%
sns.countplot(x='day',data=df,hue='gender')
plt.show()

# %%
sns.countplot(x='day',data=df,hue='smoker')
plt.show()

# %%
# df

# %%
sns.catplot(x='day',y='total_bill',data=df)
plt.show()

# %%
sns.catplot(x='day',y='total_bill',data=df,kind='swarm')
plt.show()

# %%
sns.catplot(x='day',y='total_bill',data=df,kind='violin')
plt.show()

# %%
sns.catplot(x='day',y='total_bill',data=df,kind='bar')
plt.show()

# %%
sns.catplot(x='day',y='total_bill',data=df,kind='boxen')
plt.show()

# %%
sns.catplot(x='day',y='total_bill',data=df,kind='point')
plt.show()

# %%
df2 = sns.load_dataset('titanic')
df2
# try working on titanic dataset
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %% [markdown]
# # End of seaborn
